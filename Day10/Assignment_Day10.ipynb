# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt

# %% [markdown]
# ### 10 A

# %%
path = r".\code\data\bikes.csv"
bike_data = pd.read_csv(path)
bike_data
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %%
bike_data.head()
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0  01/01/2013      00:00       0    0      1      0     6        0        1
# 1  02/01/2013      00:00      69    0     13      0    18        0        2
# 2  03/01/2013      00:00      69    2     21      6    22        1        0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125
# 4  05/01/2013      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
bike_data.describe()
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(bike_data['Berri1'],label='berri',color='red',marker='.')
plt.plot(bike_data['PierDup'],label='pierdup',color='blue',marker='.')
plt.title('Attendance')
plt.grid(axis='y')
plt.xlabel('count')
plt.ylabel('number of bikes')
plt.legend()

# %%
bike_data.index
# Out:
# RangeIndex(start=0, stop=261, step=1)

# %%
# bike_data = bike_data.drop(['weekday_name','weekday'],axis=1)   --> to drop the particular columns
bike_data['Date'] = pd.to_datetime(bike_data['Date'],format='%d/%m/%Y')

# %%
bike_data['weekday'] = bike_data['Date'].dt.weekday
bike_data['day_name'] = bike_data['Date'].dt.day_name()
bike_data.head()
# Out:
#         Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0 2013-01-01      00:00       0    0      1      0     6        0        1
# 1 2013-01-02      00:00      69    0     13      0    18        0        2
# 2 2013-01-03      00:00      69    2     21      6    22        1        0
# 3 2013-01-04      00:00      80    0     22      4    16        0      125
# 4 2013-01-05      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier  weekday   day_name
# 0              0        1    Tuesday
# 1              0        2  Wednesday
# 2              0        3   Thursday
# 3              0        4     Friday
# 4              0        5   Saturday

# %%
#bike = bike_data.loc[:,['Berri1','CSC','Mais1','Mais2','Parc','PierDup','Rachel1']]
#bike['total']= bike.sum(axis=1)
#bike
bike_data['total_bikes'] = bike_data.drop(columns=['Date','Unnamed: 1','weekday','day_name']).sum(axis=1)
# bike_data['total_bikes'] = bike_data.loc[:,['Berri1','CSC','Mais1','Mais2','Parc','PierDup','Rachel1']].sum(axis=1)
bike_data.head()
# Out:
#         Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0 2013-01-01      00:00       0    0      1      0     6        0        1
# 1 2013-01-02      00:00      69    0     13      0    18        0        2
# 2 2013-01-03      00:00      69    2     21      6    22        1        0
# 3 2013-01-04      00:00      80    0     22      4    16        0      125
# 4 2013-01-05      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier  weekday   day_name  total_bikes
# 0              0        1    Tuesday            8
# 1              0        2  Wednesday          102
# 2              0        3   Thursday          121
# 3              0        4     Friday          247
# 4              0        5   Saturday          187

# %%
zing = bike_data.groupby('weekday').agg({'total_bikes':'sum'})
zing
# Out:
#          total_bikes
# weekday
# 0             662902
# 1             705161
# 2             732606
# 3             690471
# 4             640301
# 5             463944
# 6             466577

# %%
plt.plot(zing['total_bikes'],color='magenta',marker='o')
plt.title('sum of all attendance as a function of the weekday')
plt.xlabel('weekday')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ### 10 B

# %%
titanic = pd.read_csv(r".\code\data\titanic_train.csv")
titanic.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
gender_survival = titanic.groupby('sex').agg({'sex':'count','survived':'sum'})
gender_survival
# Out:
#         sex  survived
# sex
# female  314       233
# male    577       109

# %%
plt.bar(gender_survival.index,gender_survival.survived)
# Out:
# <BarContainer object of 2 artists>

# %%
pclass_survival = titanic.groupby(['pclass']).agg({"survived":"sum"})
pclass_survival
# Out:
#         survived
# pclass
# 1            136
# 2             87
# 3            119

# %%
plt.bar(pclass_survival.index,pclass_survival.survived)
labels = [1,2,3]
plt.xticks(labels)
plt.xlabel('pclass')
plt.ylabel("survived")
plt.title('survived depends on pclass')
# Out:
# Text(0.5, 1.0, 'survived depends on pclass')

# %%
survived_more = titanic.groupby('sex').agg({'sex': 'count', 'survived': 'sum'})
survived_more.rename(columns={'sex': 'total', 'survived': 'survived'}, inplace=True)
survived_more['%survival'] = round(survived_more['survived']/survived_more['total']*100,2)
survived_more
# Out:
#         total  survived  %survival
# sex
# female    314       233      74.20
# male      577       109      18.89

# %%
zing = titanic.groupby(['pclass']).agg({'pclass':'count','survived':'sum'})
zing['percentage'] = round(zing['survived']/zing['pclass']*100,2)
zing
# Out:
#         pclass  survived  percentage
# pclass
# 1          216       136       62.96
# 2          184        87       47.28
# 3          491       119       24.24

# %% [markdown]
# ## 10 C  Roger Federer database

# %%
roger = pd.read_csv(r".\code\data\federer.csv")
roger.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
roger.columns
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
roger.columns
# roger.describe()
# roger
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
# roger.loc[roger['winner']=='Roger Federer',:]['winner'].count() / roger['winner'].count() * 100
round(roger.loc[roger['winner']=='Roger Federer',:]['winner'].size / roger['winner'].count() * 100,2)
# Out:
# 82.44

# %%
roger[['player1 double faults','player1 total points total','player2 double faults','player2 total points total']]
roger.loc[:,['player1 name','player2 name']].nunique()
# Out:
# player1 name      1
# player2 name    282
# dtype: int64

# %%
proportion_df = pd.DataFrame(round(roger['player1 double faults'] / roger['player1 total points total'], 3),columns=['double_fault_proportion_roger'])
proportion_df['double_fault_proportion_others'] = pd.DataFrame(round(roger['player2 double faults'] / roger['player2 total points total'], 3))
proportion_df
# Out:
#       double_fault_proportion_roger  double_fault_proportion_others
# 0                             0.019                           0.010
# 1                             0.000                           0.000
# 2                             0.020                           0.027
# 3                             0.046                           0.008
# 4                               NaN                             NaN
# ...                             ...                             ...
# 1174                          0.018                           0.004
# 1175                          0.000                           0.035
# 1176                          0.000                           0.000
# 1177                          0.012                           0.000
# 1178                            NaN                             NaN
#
# [1179 rows x 2 columns]

# %%
roger['surface'].unique()
roger.surface
# Out:
# 0        Indoor: Hard
# 1        Indoor: Hard
# 2        Indoor: Hard
# 3        Indoor: Hard
# 4       Outdoor: Clay
#             ...
# 1174    Outdoor: Hard
# 1175    Outdoor: Hard
# 1176    Outdoor: Hard
# 1177    Outdoor: Hard
# 1178    Outdoor: Hard
# Name: surface, Length: 1179, dtype: object

# %%
federer_surface = roger.groupby('surface').agg({'winner':'count'})
Roger_df_surface =roger.groupby('surface').agg({'winner':'count'})
Roger_df_surface.columns = ['roger_win']
Roger_df_surface
# Out:
#                 roger_win
# surface
# Indoor: Carpet         76
# Indoor: Clay            6
# Indoor: Hard          226
# Outdoor: Clay         249
# Outdoor: Grass        140
# Outdoor: Hard         482

# %%
ave_df = federer_surface.merge(Roger_df_surface,on='surface')
ave_df['avg_win_%_roger'] = round(ave_df['roger_win']/ave_df['winner'],3)
ave_df
# Out:
#                 winner  roger_win  avg_win_%_roger
# surface
# Indoor: Carpet      76         76              1.0
# Indoor: Clay         6          6              1.0
# Indoor: Hard       226        226              1.0
# Outdoor: Clay      249        249              1.0
# Outdoor: Grass     140        140              1.0
# Outdoor: Hard      482        482              1.0

# %%
roger['start date'][2],type(roger['start date'][0])
# Out:
# ('28.09.1998', str)

# %%
roger['start date'] = pd.to_datetime(roger['start date'],format = '%d.%m.%Y')

# %%
roger['start date'][2],type(roger['start date'][0])
# Out:
# (Timestamp('1998-09-28 00:00:00'), pandas._libs.tslibs.timestamps.Timestamp)

# %%
#player 1 Roger
proportion_per_day = roger.groupby('start date').agg({'player1 double faults':'sum','player1 total points total':'sum'})
proportion_per_day['proportion of double faults'] = round(proportion_per_day['player1 double faults'] / proportion_per_day['player1 total points total'],3)
proportion_per_day
# Out:
#             player1 double faults  player1 total points total  \
# start date
# 1998-07-06                    3.0                       136.0
# 1998-08-24                    0.0                         0.0
# 1998-09-28                    9.0                       384.0
# 1998-10-05                    2.0                       103.0
# 1999-01-25                    0.0                         0.0
# ...                           ...                         ...
# 2012-08-27                    7.0                       707.0
# 2012-09-14                    0.0                         0.0
# 2012-10-07                    9.0                       569.0
# 2012-10-22                    4.0                       775.0
# 2012-11-05                    7.0                       743.0
#
#             proportion of double faults
# start date
# 1998-07-06                        0.022
# 1998-08-24                          NaN
# 1998-09-28                        0.023
# ...

# %%
type(roger['year'][0])
# Out:
# numpy.int64

# %%
proportion_per_year = roger.groupby('year').agg({'player1 double faults':'sum','player1 total points total':'sum'})
proportion_per_year['proportion of double faults'] = round(proportion_per_year['player1 double faults'] / proportion_per_year['player1 total points total'],3)
proportion_per_year
# Out:
#       player1 double faults  player1 total points total  \
# year
# 1998                   14.0                       623.0
# 1999                   92.0                      4024.0
# 2000                  203.0                      9531.0
# 2001                  203.0                     11666.0
# 2002                  194.0                     11344.0
# 2003                  269.0                     13833.0
# 2004                  156.0                     11483.0
# 2005                  152.0                     13644.0
# 2006                  118.0                     15491.0
# 2007                   86.0                     12064.0
# 2008                   77.0                     12859.0
# 2009                  134.0                     12444.0
# 2010                  110.0                     12224.0
# 2011                   98.0                     11028.0
# 2012                  120.0                     12808.0
#
#       proportion of double faults
# year
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(proportion_per_year.index, proportion_per_year['proportion of double faults'], marker='*', linestyle='-', color='Magenta')
plt.title("proportion of double faults per year")
plt.xlabel("Year")
plt.ylabel("proportion")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10 D

# %%
from scipy.fft import fft, fftfreq

# %%
Fs = 500  
t = np.linspace(0, 1, Fs, endpoint=False)  
signal = np.sin(2 * np.pi * 5 * t) + np.sin(2 * np.pi * 50 * t)


fft_values = fft(signal)
freqs = fftfreq(Fs, 1 / Fs)

fig, axs = plt.subplots(2, 1, figsize=(10, 8))


axs[0].plot(t, signal, label='Signal (5Hz + 50Hz)')
axs[0].set_title('Time Domain Signal (5Hz + 50Hz)')
axs[0].set_xlabel('Time [s]')
axs[0].set_ylabel('Amplitude')
axs[0].grid(True)

axs[1].plot(freqs[:Fs//2], np.abs(fft_values[:Fs//2]))
axs[1].set_title('FFT of 5Hz + 50Hz Signal')
axs[1].set_xlabel('Frequency [Hz]')
axs[1].set_ylabel('Magnitude')
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## E. Plotting normal random numbers and show that addition of two Gaussian is Gaussian and addition of all is Gaussian

# %%
np.random.seed(0)

# %%
x1 = np.random.normal(0, 1, 1000)
x2 = np.random.normal(0, 1, 1000)
x3 = np.random.normal(0, 1, 1000)
x4 = np.random.normal(0, 1, 1000)
x5 = np.random.normal(0, 1, 1000)
x6 = np.random.normal(0, 1, 1000)
x7 = np.random.normal(0, 1, 1000)

# %%
sum_two = x1 + x2
sum_all = x1 + x2 + x3 + x4 + x5 + x6 + x7

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(x1, bins=30, alpha=0.5, label='x1')
plt.hist(x2, bins=30, alpha=0.5, label='x2')
plt.hist(sum_two, bins=30, alpha=0.7, label='x1 + x2', color='magenta')
plt.legend()
plt.title('Sum of Two Gaussian Distributions')
# Out:
# Text(0.5, 1.0, 'Sum of Two Gaussian Distributions')

# %%
plt.subplot(1, 2, 2)
plt.hist(sum_all, bins=30, alpha=0.7, label='Sum of All Gaussian', color='green')
plt.legend()
plt.title('Sum of Many Gaussian Distributions')
plt.tight_layout()
plt.show()
